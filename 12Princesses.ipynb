# %%
import nltk 
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.probability import FreqDist
from string import punctuation

# %%
nltk.download('stopwords')

# %%
tknlst = []
filepath = 'datasets_12dancingprincesses.txt'
with open(filepath,'r') as f:
    for line in f:
        cline = line.strip().lower()
        
        if cline =='': 
            pass
        else:
            words=word_tokenize(cline)
            for token in words:
                tknlst.append(token)

# %%
x = 0
for word in tknlst:
    if word ==';':
        x +=1

# %%
x
# Out:
# 35

# %%
len(tknlst)
# Out:
# 1853

# %%
eng_stopwords = stopwords.words('english')
eng_stopwords[:5]
# Out:
# ['i', 'me', 'my', 'myself', 'we']

# %%
fq_dist = FreqDist(tknlst)
#len(fq_dist) #477 kind of repited words 
fq_dist
# Out:
# FreqDist({'!': 2,
#           '(': 1,
#           ')': 1,
#           ',': 102,
#           '--': 2,
#           '.': 39,
#           ':': 8,
#           ';': 35,
#           '?': 3,
#           'a': 22,
#           'able': 1,
#           'about': 2,
#           'adventure': 1,
#           'afraid': 1,
#           'after': 4,
#           'afterwards': 1,
#           'again': 4,
#           'all': 24,
#           'already': 1,
#           'always': 2,
#           'am': 6,
#           'an': 2,
#           'and': 78,
#           'another': 2,
#           'answered': 2,
#           'any': 3,
#           'approach': 1,
#           'are': 3,
#           'as': 19,
#           'asked': 4,
#           'asleep': 3,
#           'at': 7,
#           'away': 4,
#           'awoke': 1,
#           'back': 1,
#           'battle': 1,
#           'be': 10,
#           'beautiful': 1,
#           'beautifully': 1,
#           'become': 1,
#           'bed': 6,
#           'beds': 2,
# ...

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
punc = []
eng_st =  []

# %%
punc
# Out:
# []

# %%
new_list = []

# %%
#fq_dist = FreqDist(tknlst)
for word in tknlst:
    if word in punctuation:
        tknlst.remove(word)
        punc.append(word)
    
    if word in eng_stopwords:
        tknlst.remove(word)
        eng_st.append(word)

# %%
punc[:5]
# Out:
# ['.', ';', ',', ';', ';']

# %%
len(punc)
# Out:
# 190

# %%
eng_st[:5]
# Out:
# ['the', 'there', 'a', 'who', 'they']

# %%
len(eng_st)
# Out:
# 603

# %%
len(tknlst)
# Out:
# 1059

# %%
new_fq =FreqDist(tknlst)
new_fq.com
# Out:
# FreqDist({'--': 2,
#           'a': 12,
#           'able': 1,
#           'adventure': 1,
#           'afraid': 1,
#           'after': 1,
#           'afterwards': 1,
#           'all': 16,
#           'already': 1,
#           'always': 2,
#           'am': 4,
#           'an': 1,
#           'and': 6,
#           'another': 2,
#           'answered': 2,
#           'any': 1,
#           'approach': 1,
#           'are': 3,
#           'as': 9,
#           'asked': 4,
#           'asleep': 3,
#           'at': 3,
#           'away': 4,
#           'awoke': 1,
#           'back': 1,
#           'battle': 1,
#           'be': 7,
#           'beautiful': 1,
#           'beautifully': 1,
#           'become': 1,
#           'bed': 6,
#           'beds': 2,
#           'been': 2,
#           'befall': 1,
#           'before': 1,
#           'before.': 1,
#           'began': 1,
#           'begin': 1,
#           'behind': 1,
#           'best': 1,
#           'better': 1,
# ...

# %%
new_frq = FreqDist(tknlst)
new_frq

# %%
new = FreqDist(tknlst)
new.most_common(10)
# Out:
# [('the', 91),
#  ('’', 27),
#  ('‘', 21),
#  ('soldier', 19),
#  ('they', 19),
#  ('princesses', 17),
#  ('was', 17),
#  ('said', 16),
#  ('all', 16),
#  ('king', 15)]

# %%
for word in fq_dist:
    if word in punctuation:
        fq_dist.remove(word)
        punc.append(word)

# %%
for line in open(filepath,'r'):
    line =line.rstrip()
    cline = word_tokenize(line)
    print(cline)
